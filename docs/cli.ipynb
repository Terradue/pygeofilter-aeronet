# %% [markdown]
# # Command Line Interface
#
# `pygeofilter-aeronet` can be used as a Command Line Interface (CLI).

# %%
aeronet-client --help
# Out:
# Traceback (most recent call last):
#   File "/home/stripodi/.local/bin/aeronet-client", line 5, in <module>
#     from pygeofilter_aeronet.cli import main
#   File "/home/stripodi/.local/lib/python3.10/site-packages/pygeofilter_aeronet/cli.py", line 67, in <module>
#     def search(
#   File "/home/stripodi/.local/lib/python3.10/site-packages/click/decorators.py", line 346, in decorator
#     _param_memo(f, cls(param_decls, **attrs))
#   File "/home/stripodi/.local/lib/python3.10/site-packages/click/core.py", line 3277, in __init__
#     super().__init__(param_decls, required=required, **attrs)
# TypeError: Parameter.__init__() got an unexpected keyword argument 'help'
# : 1

# %% [markdown]
# ## Search

# %%
aeronet-client search --help

# %% [markdown]
# i.e.

# %%
aeronet-client search --filter '{"op":"and","args":[{"op":"eq","args":[{"property":"site"},"Cart_Site"]},{"op":"eq","args":[{"property":"data_type"},"AOD20"]},{"op":"eq","args":[{"property":"format"},"csv"]},{"op":"eq","args":[{"property":"data_format"},"daily-average"]},{"op":"t_after","args":[{"property":"time"},{"timestamp":"2000-06-01T00:00:00Z"}]},{"op":"t_before","args":[{"property":"time"},{"timestamp":"2000-06-14T23:59:59Z"}]}]}'
