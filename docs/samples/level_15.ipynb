# %% [markdown]
# # Level 1.5 data from all sites with available data for all AOD points
#
# Define a cql2-json filter for:
#
# https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?year=2000&month=6&day=1&year2=2000&month2=6&day2=14&AOD15=1&AVG=10

# %%
from pathlib import Path
from pystac import Item

import json
import sys

out_dir: Path = Path('.')

cql2_filter = {
    "op": "and",
    "args": [
        {"op": "eq", "args": [{"property": "data_type"}, "AOD15"]},
        {"op": "eq", "args": [{"property": "format"}, "csv"]},
        {"op": "eq", "args": [{"property": "data_format"}, "all-points"]},
        {
            "op": "t_after",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-01T00:00:00Z"},
            ],
        },
        {
            "op": "t_before",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-14T23:59:59Z"},
            ],
        },
    ],
}

json.dump(cql2_filter, sys.stdout, indent=2)
# Out:
# {
#   "op": "and",
#   "args": [
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_type"
#         },
#         "AOD15"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "format"
#         },
#         "csv"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_format"
#         },
#         "all-points"
#       ]
#     },
#     {
#       "op": "t_after",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-01T00:00:00Z"
#         }
#       ]
#     },
#     {
#       "op": "t_before",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-14T23:59:59Z"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Execute the `search` operation

# %%
from pygeofilter_aeronet import aeronet_search

item: Item = aeronet_search(
    cql2_filter=cql2_filter,
    output_dir=out_dir
)

json.dump(item.to_dict(), sys.stdout, indent=2)
# Out:
# 2025-11-14 18:04:17.940 | SUCCESS  | pygeofilter_aeronet:aeronet_search:231 - Query on https://aeronet.gsfc.nasa.gov successfully obtained data:
# 2025-11-14 18:04:18.751 | SUCCESS  | pygeofilter_aeronet:aeronet_search:239 - Data saved to to CSV file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/0c0a6b0a-fb4c-4930-abbc-374e447739e8.csv
# 2025-11-14 18:04:18.976 | SUCCESS  | pygeofilter_aeronet:aeronet_search:270 - Data saved to GeoParquet file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/0c0a6b0a-fb4c-4930-abbc-374e447739e8.parquet
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [],
#   "id": "urn:uuid:0c0a6b0a-fb4c-4930-abbc-374e447739e8",
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -157.789717,
#           -34.555425
#         ],
#         [
#           166.9159,
#           -34.555425
#         ],
#         [
#           166.9159,
#           64.742805
#         ],
#         [
#           -157.789717,
#           64.742805
#         ],
#         [
#           -157.789717,
#           -34.555425
#         ]
#       ]
#     ]
#   },
#   "bbox": [
#     -157.789717,
#     -34.555425,
#     166.9159,
#     64.742805
#   ],
#   "properties": {
#     "datetime": "2025-11-14T18:04:19.064758Z"
#   },
#   "links": [
#     {
#       "rel": "related",
#       "href": "https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?AOD15=1&if_no_html=1&AVG=10&year=2000&month=6&day=1&hour=0&year2=2000&month2=6&day2=14&hour2=23",
#       "type": "text/csv",
#       "title": "AERONET Web Service search"
#     }
#   ],
#   "assets": {
#     "csv": {
#       "href": "0c0a6b0a-fb4c-4930-abbc-374e447739e8.csv",
#       "type": "text/csv",
#       "description": "Search result - CVS Format"
#     },
#     "geoparquet": {
#       "href": "0c0a6b0a-fb4c-4930-abbc-374e447739e8.parquet",
#       "type": "application/vnd.apache.parquet",
#       "description": "Search result - GeoParquet Format"
#     }
#   }
# }

# %% [markdown]
# ## Visualize the results as Data Frame

# %%
from geopandas import read_parquet
from geopandas.geodataframe import GeoDataFrame

geoparquet_file: str = item.get_assets()['geoparquet'].href
geoparquet_data: GeoDataFrame = read_parquet(geoparquet_file)

geoparquet_data
# Out:
#         AERONET_Site Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  \
# 0      Alta_Floresta       01:06:2000       10:35:11          153
# 1      Alta_Floresta       01:06:2000       10:38:01          153
# 2      Alta_Floresta       01:06:2000       10:41:20          153
# 3      Alta_Floresta       01:06:2000       10:45:17          153
# 4      Alta_Floresta       01:06:2000       10:50:02          153
# ...              ...              ...            ...          ...
# 17678  Sioux_Falls_X       12:06:2000       00:34:12          164
# 17679  Sioux_Falls_X       12:06:2000       00:51:30          164
# 17680  Sioux_Falls_X       12:06:2000       00:57:49          164
# 17681  Sioux_Falls_X       14:06:2000       15:43:51          166
# 17682  Sioux_Falls_X       14:06:2000       15:58:53          166
#
#        Day_of_Year(Fraction)  AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  \
# 0                 153.441100      -999.0 -999.000000   0.036698     -999.0
# 1                 153.443067      -999.0 -999.000000   0.035715     -999.0
# 2                 153.445370      -999.0 -999.000000   0.030944     -999.0
# 3                 153.448113      -999.0 -999.000000   0.030626     -999.0
# 4                 153.451412      -999.0 -999.000000   0.031351     -999.0
# ...                      ...         ...         ...        ...        ...
# 17678             164.023750      -999.0    0.045764   0.050797     -999.0
# 17679             164.035764      -999.0    0.049516   0.054518     -999.0
# 17680             164.040150      -999.0    0.048396   0.053796     -999.0
# 17681             166.655451      -999.0    0.014850   0.016013     -999.0
# 17682             166.665891      -999.0    0.014560   0.016502     -999.0
#
#        AOD_779nm  ...  Exact_Wavelengths_of_PW(um)_935nm  \
# 0         -999.0  ...                             0.9364
# 1         -999.0  ...                             0.9364
# 2         -999.0  ...                             0.9364
# 3         -999.0  ...                             0.9364
# 4         -999.0  ...                             0.9364
# ...          ...  ...                                ...
# 17678     -999.0  ...                             0.9353
# 17679     -999.0  ...                             0.9353
# 17680     -999.0  ...                             0.9353
# 17681     -999.0  ...                             0.9353
# 17682     -999.0  ...                             0.9353
#
#        Exact_Wavelengths_of_AOD(um)_681nm  Exact_Wavelengths_of_AOD(um)_709nm  \
# 0                                  -999.0                              -999.0
# 1                                  -999.0                              -999.0
# 2                                  -999.0                              -999.0
# 3                                  -999.0                              -999.0
# 4                                  -999.0                              -999.0
# ...                                   ...                                 ...
# 17678                              -999.0                              -999.0
# 17679                              -999.0                              -999.0
# 17680                              -999.0                              -999.0
# 17681                              -999.0                              -999.0
# 17682                              -999.0                              -999.0
#
#        Exact_Wavelengths_of_AOD(um)_Empty  \
# 0                                  -999.0
# 1                                  -999.0
# 2                                  -999.0
# 3                                  -999.0
# 4                                  -999.0
# ...                                   ...
# 17678                              -999.0
# 17679                              -999.0
# 17680                              -999.0
# 17681                              -999.0
# 17682                              -999.0
#
#        Exact_Wavelengths_of_AOD(um)_Empty.1  \
# 0                                    -999.0
# 1                                    -999.0
# 2                                    -999.0
# 3                                    -999.0
# 4                                    -999.0
# ...                                     ...
# 17678                                -999.0
# 17679                                -999.0
# 17680                                -999.0
# 17681                                -999.0
# 17682                                -999.0
#
#        Exact_Wavelengths_of_AOD(um)_Empty.2  \
# 0                                    -999.0
# 1                                    -999.0
# 2                                    -999.0
# 3                                    -999.0
# 4                                    -999.0
# ...                                     ...
# 17678                                -999.0
# 17679                                -999.0
# 17680                                -999.0
# 17681                                -999.0
# 17682                                -999.0
#
#        Exact_Wavelengths_of_AOD(um)_Empty.3  \
# 0                                    -999.0
# 1                                    -999.0
# 2                                    -999.0
# 3                                    -999.0
# 4                                    -999.0
# ...                                     ...
# 17678                                -999.0
# 17679                                -999.0
# 17680                                -999.0
# 17681                                -999.0
# 17682                                -999.0
#
#        Exact_Wavelengths_of_AOD(um)_Empty.4                    geometry  \
# 0                                    -999.0  POINT (-56.10445 -9.87134)
# 1                                    -999.0  POINT (-56.10445 -9.87134)
# 2                                    -999.0  POINT (-56.10445 -9.87134)
# 3                                    -999.0  POINT (-56.10445 -9.87134)
# 4                                    -999.0  POINT (-56.10445 -9.87134)
# ...                                     ...                         ...
# 17678                                -999.0  POINT (-96.62598 43.73628)
# 17679                                -999.0  POINT (-96.62598 43.73628)
# 17680                                -999.0  POINT (-96.62598 43.73628)
# 17681                                -999.0  POINT (-96.62598 43.73628)
# 17682                                -999.0  POINT (-96.62598 43.73628)
#
#                  datetime
# 0     2000-06-01 10:35:11
# 1     2000-06-01 10:38:01
# 2     2000-06-01 10:41:20
# 3     2000-06-01 10:45:17
# 4     2000-06-01 10:50:02
# ...                   ...
# 17678 2000-06-12 00:34:12
# 17679 2000-06-12 00:51:30
# 17680 2000-06-12 00:57:49
# 17681 2000-06-14 15:43:51
# 17682 2000-06-14 15:58:53
#
# [17683 rows x 116 columns]

# %% [markdown]
# ## Visualize results on Map screen

# %%
from folium import (
    GeoJson,
    LayerControl,
    Map
)
from folium.plugins import (
    Fullscreen
)
from IPython.display import (
    display,
    HTML
)

map: Map = Map()
layer_control = LayerControl(position="topright", collapsed=True)
fullscreen = Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints: GeoJson = GeoJson(
    geoparquet_data.dissolve(by='AERONET_Site').to_json(default=str),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds()) # type: ignore not to important for the demo
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cae0c126cd500f5f1f2584c396ed6deb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cae0c126cd500f5f1f2584c396ed6deb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cae0c126cd500f5f1f2584c396ed6deb = L.map(
#                 &quot;map_cae0c126cd500f5f1f2584c396ed6deb&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5546c0dfcc19521e943e1748c270b88d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5546c0dfcc19521e943e1748c270b88d.addTo(map_cae0c126cd500f5f1f2584c396ed6deb);
#
#
#         function geo_json_938734cf18ba073f2902d1d924d73e68_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_938734cf18ba073f2902d1d924d73e68_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_938734cf18ba073f2902d1d924d73e68 = L.geoJson(null, {
#                 onEachFeature: geo_json_938734cf18ba073f2902d1d924d73e68_onEachFeature,
#
#                 style: geo_json_938734cf18ba073f2902d1d924d73e68_styler,
#             ...{
# }
#         });
#
#         function geo_json_938734cf18ba073f2902d1d924d73e68_add (data) {
#             geo_json_938734cf18ba073f2902d1d924d73e68
#                 .addData(data);
#         }
#             geo_json_938734cf18ba073f2902d1d924d73e68_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-62.358333, -10.76], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Abracos_Hill&quot;, &quot;properties&quot;: {&quot;340-440_Angstrom_Exponent&quot;: 1.750086, &quot;380-500_Angstrom_Exponent&quot;: 1.647492, &quot;440-675_Angstrom_Exponent&quot;: 1.836643, &quot;440-675_Angstrom_Exponent[Polar]&quot;: -999.0, &quot;440-870_Angstrom_Exponent&quot;: 1.634035, &quot;500-870_Angstrom_Exponent&quot;: 1.62342, &quot;AERONET_Instrument_Number&quot;: 12, &quot;AERONET_Site_Name&quot;: &quot;Abracos_Hill&quot;, &quot;AOD_1020nm&quot;: 0.023195, &quot;AOD_1640nm&quot;: -999.0, &quot;AOD_340nm&quot;: 0.161211, &quot;AOD_380nm&quot;: 0.133593, &quot;AOD_400nm&quot;: -999.0, &quot;AOD_412nm&quot;: -999.0, &quot;AOD_440nm&quot;: 0.102617, &quot;AOD_443nm&quot;: -999.0, &quot;AOD_490nm&quot;: -999.0, &quot;AOD_500nm&quot;: 0.085206, &quot;AOD_510nm&quot;: -999.0, &quot;AOD_531nm&quot;: -999.0, &quot;AOD_532nm&quot;: -999.0, &quot;AOD_551nm&quot;: -999.0, &quot;AOD_555nm&quot;: -999.0, &quot;AOD_560nm&quot;: -999.0, &quot;AOD_620nm&quot;: -999.0, &quot;AOD_667nm&quot;: -999.0, &quot;AOD_675nm&quot;: 0.04749, &quot;AOD_681nm&quot;: -999.0, &quot;AOD_709nm&quot;: -999.0, &quot;AOD_779nm&quot;: -999.0, &quot;AOD_865nm&quot;: -999.0, &quot;AOD_870nm&quot;: 0.034904, &quot;AOD_Empty&quot;: -999.0, &quot;AOD_Empty.1&quot;: -999.0, &quot;AOD_Empty.2&quot;: -999.0, &quot;AOD_Empty.3&quot;: -999.0, &quot;AOD_Empty.4&quot;: -999.0, &quot;Data_Quality_Level&quot;: &quot;lev15&quot;, &quot;Date(dd:mm:yyyy)&quot;: &quot;01:06:2000&quot;, &quot;Day_of_Year&quot;: 153, &quot;Day_of_Year(Fraction)&quot;: 153.530081, &quot;Exact_Wavelengths_of_AOD(um)_1020nm&quot;: 1.0214, &quot;Exact_Wavelengths_of_AOD(um)_1640nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_340nm&quot;: 0.3399, &quot;Exact_Wavelengths_of_AOD(um)_380nm&quot;: 0.3807, &quot;Exact_Wavelengths_of_AOD(um)_400nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_412nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_440nm&quot;: 0.4402, &quot;Exact_Wavelengths_of_AOD(um)_443nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_490nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_500nm&quot;: 0.5005, &quot;Exact_Wavelengths_of_AOD(um)_510nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_531nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_532nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_551nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_555nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_560nm&quot;: -999.0, &quot;Exact_Wavelengths_of_AOD(um)_620nm&quot;: -999.0, &quot;Exact_Waveleng
