# %% [markdown]
# # Geographical search
#
# Define a cql2-json filter for:
#
# SDA20=1&if_no_html=1&AVG=20&year=2000&month=6&day=1&hour=0&year2=2000&month2=6&day2=14&hour2=23&lon1=8.0&lat1=44.0&lon2=14.0&lat2=48.0

# %%
from pathlib import Path
from pystac import Item

import json
import sys

out_dir: Path = Path('.')

cql2_filter = {
    "op": "and",
    "args": [
        {"op": "eq", "args": [{"property": "data_type"}, "SDA20"]},
        {"op": "eq", "args": [{"property": "format"}, "csv"]},
        {"op": "eq", "args": [{"property": "data_format"}, "daily-average"]},
        {
            "op": "t_after",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-01T00:00:00Z"},
            ],
        },
        {
            "op": "t_before",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-14T23:59:59Z"},
            ],
        },
        {
            "op": "s_intersects",
            "args": [
                {"property": "geometry"},
                {
                    "type": "Polygon",
                    "coordinates": [
                        [
                            [8.0, 44.0],
                            [14.0, 44.0],
                            [14.0, 48.0],
                            [8.0, 48.0],
                            [8.0, 44.0],
                        ]
                    ],
                },
            ],
        },
    ],
}

json.dump(cql2_filter, sys.stdout, indent=2)
# Out:
# {
#   "op": "and",
#   "args": [
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_type"
#         },
#         "SDA20"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "format"
#         },
#         "csv"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_format"
#         },
#         "daily-average"
#       ]
#     },
#     {
#       "op": "t_after",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-01T00:00:00Z"
#         }
#       ]
#     },
#     {
#       "op": "t_before",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-14T23:59:59Z"
#         }
#       ]
#     },
#     {
#       "op": "s_intersects",
#       "args": [
#         {
#           "property": "geometry"
#         },
#         {
#           "type": "Polygon",
#           "coordinates": [
#             [
#               [
#                 8.0,
#                 44.0
#               ],
#               [
#                 14.0,
#                 44.0
#               ],
#               [
#                 14.0,
#                 48.0
#               ],
#               [
#                 8.0,
#                 48.0
#               ],
#               [
#                 8.0,
#                 44.0
#               ]
#             ]
#           ]
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Execute the `search` operation

# %%
from pygeofilter_aeronet import aeronet_search

item: Item = aeronet_search(
    cql2_filter=cql2_filter,
    output_dir=out_dir,
    verbose=True
)

json.dump(item.to_dict(), sys.stdout, indent=2)
# Out:
# 2025-11-13 15:54:58.301 | WARNING  | pygeofilter_aeronet.utils:wrapper:71 - GET https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?year=2000&month=6&day=1&AVG=20&SDA20=1&year2=2000&month2=6&day2=14&hour=0&hour2=23&lat1=44.0&lon1=8.0&lat2=48.0&lon2=14.0&if_no_html=1
# 2025-11-13 15:54:58.301 | WARNING  | pygeofilter_aeronet.utils:wrapper:75 - > Host: aeronet.gsfc.nasa.gov
# 2025-11-13 15:54:58.302 | WARNING  | pygeofilter_aeronet.utils:wrapper:75 - > Accept: */*
# 2025-11-13 15:54:58.302 | WARNING  | pygeofilter_aeronet.utils:wrapper:75 - > Accept-Encoding: gzip, deflate
# 2025-11-13 15:54:58.302 | WARNING  | pygeofilter_aeronet.utils:wrapper:75 - > Connection: keep-alive
# 2025-11-13 15:54:58.302 | WARNING  | pygeofilter_aeronet.utils:wrapper:75 - > User-Agent: python-httpx/0.28.1
# 2025-11-13 15:54:58.302 | WARNING  | pygeofilter_aeronet.utils:wrapper:77 - >
# 2025-11-13 15:54:59.277 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:99 - < 200 OK
# 2025-11-13 15:54:59.278 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < date: Thu, 13 Nov 2025 14:54:59 GMT
# 2025-11-13 15:54:59.278 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < server: Apache
# 2025-11-13 15:54:59.279 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < strict-transport-security: max-age=31557600
# 2025-11-13 15:54:59.279 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < vary: Origin
# 2025-11-13 15:54:59.279 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < keep-alive: timeout=15, max=100
# 2025-11-13 15:54:59.279 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < connection: Keep-Alive
# 2025-11-13 15:54:59.280 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < transfer-encoding: chunked
# 2025-11-13 15:54:59.280 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:103 - < content-type: text/plain
# 2025-11-13 15:54:59.280 | SUCCESS  | pygeofilter_aeronet.utils:wrapper:105 -
# 2025-11-13 15:54:59.282 | SUCCESS  | pygeofilter_aeronet:aeronet_search:230 - Query on https://aeronet.gsfc.nasa.gov successfully obtained data:
# 2025-11-13 15:54:59.284 | SUCCESS  | pygeofilter_aeronet:aeronet_search:238 - Data saved to to CSV file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/27ee00b9-612f-4732-aee7-cf6c0e436150.csv
# 2025-11-13 15:54:59.288 | SUCCESS  | pygeofilter_aeronet:aeronet_search:249 - Data saved to GeoParquet file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/27ee00b9-612f-4732-aee7-cf6c0e436150.parquet
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [],
#   "id": "urn:uuid:27ee00b9-612f-4732-aee7-cf6c0e436150",
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           8.6267,
#           45.3139
#         ],
#         [
#           12.5083,
#           45.3139
#         ],
#         [
#           12.5083,
#           45.80305
#         ],
#         [
#           8.6267,
#           45.80305
#         ],
#         [
#           8.6267,
#           45.3139
#         ]
#       ]
#     ]
#   },
#   "bbox": [
#     8.6267,
#     45.3139,
#     12.5083,
#     45.80305
#   ],
#   "properties": {
#     "datetime": "2025-11-13T15:54:59.310511Z"
#   },
#   "links": [
#     {
#       "rel": "related",
#       "href": "https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?SDA20=1&if_no_html=1&AVG=20&year=2000&month=6&day=1&hour=0&year2=2000&month2=6&day2=14&hour2=23&lon1=8.0&lat1=44.0&lon2=14.0&lat2=48.0",
#       "type": "text/csv",
#       "title": "AERONET Web Service search"
#     }
#   ],
#   "assets": {
#     "csv": {
#       "href": "27ee00b9-612f-4732-aee7-cf6c0e436150.csv",
#       "type": "text/csv",
#       "description": "Search result - CVS Format"
#     },
#     "geoparquet": {
#       "href": "27ee00b9-612f-4732-aee7-cf6c0e436150.parquet",
#       "type": "application/vnd.apache.parquet",
#       "description": "Search result - GeoParquet Format"
#     }
#   }
# }

# %% [markdown]
# ## Visualize the results as Data Frame

# %%
from geopandas import read_parquet
from geopandas.geodataframe import GeoDataFrame

geoparquet_file: str = item.get_assets()['geoparquet'].href
geoparquet_data: GeoDataFrame = read_parquet(geoparquet_file)

geoparquet_data
# Out:
#                              geometry Date_(dd:mm:yyyy) Time_(hh:mm:ss)  \
# AERONET_Site
# Ispra         POINT (8.6267 45.80305)        31:05:2000        12:00:00
# Venise        POINT (12.5083 45.3139)        31:05:2000        12:00:00
#
#               Day_of_Year  Total_AOD_500nm[tau_a]  Fine_Mode_AOD_500nm[tau_f]  \
# AERONET_Site
# Ispra                 152             -999.000000                 -999.000000
# Venise                152                0.702868                    0.691315
#
#               Coarse_Mode_AOD_500nm[tau_c]  FineModeFraction_500nm[eta]  \
# AERONET_Site
# Ispra                          -999.000000                  -999.000000
# Venise                            0.011553                     0.983048
#
#               2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]  \
# AERONET_Site
# Ispra                                               -999.000000
# Venise                                                 0.004935
#
#               RMSE_Fine_Mode_AOD_500nm[Dtau_f]  ...  \
# AERONET_Site                                    ...
# Ispra                               -999.00000  ...
# Venise                                 0.20148  ...
#
#               N[dAE/dln(wavelength)-Total_500nm[alphap]]  \
# AERONET_Site
# Ispra                                                  0
# Venise                                                23
#
#               N[AE-Fine_Mode_500nm[alpha_f]]  \
# AERONET_Site
# Ispra                                      0
# Venise                                    23
#
#               N[dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]]  \
# AERONET_Site
# Ispra                                                        0
# Venise                                                      23
#
#               Data_Quality_Level  AERONET_Instrument_Number  \
# AERONET_Site
# Ispra                      lev20                         80
# Venise                     lev20                        112
#
#               AERONET_Site_Name  Site_Latitude(Degrees)  \
# AERONET_Site
# Ispra                     Ispra                45.80305
# Venise                   Venise                45.31390
#
#               Site_Longitude(Degrees)  Site_Elevation(m)  Unnamed: 34
# AERONET_Site
# Ispra                          8.6267              235.0          NaN
# Venise                        12.5083               10.0          NaN
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Visualize results on Map screen

# %%
from folium import (
    GeoJson,
    LayerControl,
    Map
)
from folium.plugins import (
    Fullscreen
)
from IPython.display import (
    display,
    HTML
)

map: Map = Map()
layer_control = LayerControl(position="topright", collapsed=True)
fullscreen = Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints: GeoJson = GeoJson(
    geoparquet_data.dissolve(by='AERONET_Site').to_json(),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds()) # type: ignore not to important for the demo
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c27c9b84a33e8e1c89157c8d631d12b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c27c9b84a33e8e1c89157c8d631d12b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c27c9b84a33e8e1c89157c8d631d12b7 = L.map(
#                 &quot;map_c27c9b84a33e8e1c89157c8d631d12b7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e7588b6bdd2e573021a0f74e9ffc2f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e7588b6bdd2e573021a0f74e9ffc2f9.addTo(map_c27c9b84a33e8e1c89157c8d631d12b7);
#
#
#         function geo_json_6c6a293b84a8608eaa6792ca494a8044_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6c6a293b84a8608eaa6792ca494a8044_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6c6a293b84a8608eaa6792ca494a8044 = L.geoJson(null, {
#                 onEachFeature: geo_json_6c6a293b84a8608eaa6792ca494a8044_onEachFeature,
#
#                 style: geo_json_6c6a293b84a8608eaa6792ca494a8044_styler,
#             ...{
# }
#         });
#
#         function geo_json_6c6a293b84a8608eaa6792ca494a8044_add (data) {
#             geo_json_6c6a293b84a8608eaa6792ca494a8044
#                 .addData(data);
#         }
#             geo_json_6c6a293b84a8608eaa6792ca494a8044_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [12.5083, 45.3139], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]&quot;: 0.004935, &quot;AE-Fine_Mode_500nm[alpha_f]&quot;: 1.471693, &quot;AERONET_Instrument_Number&quot;: 112, &quot;AERONET_Site&quot;: &quot;Venise&quot;, &quot;AERONET_Site_Name&quot;: &quot;Venise&quot;, &quot;Angstrom_Exponent(AE)-Total_500nm[alpha]&quot;: 1.444095, &quot;Coarse_Mode_AOD_500nm[tau_c]&quot;: 0.011553, &quot;Data_Quality_Level&quot;: &quot;lev20&quot;, &quot;Date_(dd:mm:yyyy)&quot;: &quot;31:05:2000&quot;, &quot;Day_of_Year&quot;: 152, &quot;FineModeFraction_500nm[eta]&quot;: 0.983048, &quot;Fine_Mode_AOD_500nm[tau_f]&quot;: 0.691315, &quot;N[2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]]&quot;: 23, &quot;N[AE-Fine_Mode_500nm[alpha_f]]&quot;: 23, &quot;N[Angstrom_Exponent(AE)-Total_500nm[alpha]]&quot;: 23, &quot;N[Coarse_Mode_AOD_500nm[tau_c]]&quot;: 23, &quot;N[FineModeFraction_500nm[eta]]&quot;: 23, &quot;N[Fine_Mode_AOD_500nm[tau_f]]&quot;: 23, &quot;N[RMSE_Coarse_Mode_AOD_500nm[Dtau_c]]&quot;: 23, &quot;N[RMSE_FineModeFraction_500nm[Deta]]&quot;: 23, &quot;N[RMSE_Fine_Mode_AOD_500nm[Dtau_f]]&quot;: 23, &quot;N[Total_AOD_500nm[tau_a]]&quot;: 23, &quot;N[dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]]&quot;: 23, &quot;N[dAE/dln(wavelength)-Total_500nm[alphap]]&quot;: 23, &quot;RMSE_Coarse_Mode_AOD_500nm[Dtau_c]&quot;: 0.200755, &quot;RMSE_FineModeFraction_500nm[Deta]&quot;: 0.249058, &quot;RMSE_Fine_Mode_AOD_500nm[Dtau_f]&quot;: 0.20148, &quot;Site_Elevation(m)&quot;: 10.0, &quot;Site_Latitude(Degrees)&quot;: 45.3139, &quot;Site_Longitude(Degrees)&quot;: 12.5083, &quot;Time_(hh:mm:ss)&quot;: &quot;12:00:00&quot;, &quot;Total_AOD_500nm[tau_a]&quot;: 0.702868, &quot;Unnamed: 34&quot;: null, &quot;dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]&quot;: 1.797454, &quot;dAE/dln(wavelength)-Total_500nm[alphap]&quot;: 1.962982}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [12.5083, 45.3139], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]&quot;: 0.003788, &quot;AE-Fine_Mode_500nm[alpha_f]&quot;: 1.920015, &quot;AERONET_Instrument_Number&quot;: 112, &quot;AERONET_Site&quot;: &quot;Venise&quot;, &quot;AERONET_Site_Name&quot;: &quot;Venise&quot;, &quot;Angstrom_Exponent(AE)-Total_500nm[alpha]&quot;: 1.816809, &quot;Coarse_Mode_AOD_500nm[tau_c]&quot;: 0.00823, &quot;Data_Quality_Level&quot;: &quot;lev20&quot
